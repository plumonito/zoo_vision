# %%
import cv2
import matplotlib.pyplot as plt

# %%
# AXIS P1346 Network Camera
# cap = cv2.VideoCapture("http://daniel:PwU82-!MnG@192.168.0.34/mjpg/video.mjpg")

cap = cv2.VideoCapture("rtsp://daniel:PwU82-!MnG@192.168.0.29")
print(cap.isOpened())
im = cap.read()
# Out:
# True

# %%
display(im[1].shape)
plt.imshow(im[1])
# Out:
# (1520, 2688, 3)
